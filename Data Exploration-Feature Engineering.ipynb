# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Libraries

# %%
df = pd.read_excel('Train_dataset.xlsx')

# %%
df.head()
# Out:
#         City        State  Type  Population [2011]  Popuation [2001]  \
# 0     Mumbai  Maharashtra   M.C         12442373.0        11978450.0
# 1      Delhi        Delhi   M.C         11007835.0         9879172.0
# 2  Bangalore    Karnataka  MPUA          8436675.0         4301326.0
# 3  Hyderabad    Telangana  MPUA          6809970.0         3637483.0
# 4  Ahmedabad      Gujarat  MPUA          5570585.0         3520085.0
#
#    Sex Ratio  Median Age  Avg Temp     SWM  Toilets Avl  Water Purity  \
# 0      878.0        23.0      32.0  MEDIUM        219.0         150.0
# 1      858.0        27.0      30.0  MEDIUM        215.0         196.0
# 2      936.0        28.0      37.0    HIGH        212.0         102.0
# 3      930.0        23.0      31.0  MEDIUM        217.0         118.0
# 4      852.0        29.0      25.0     LOW        227.0         109.0
#
#     H Index  Female Population  # of hospitals  Foreign Visitors  Covid Cases
# ...

# %%
sns.pairplot(df)

# %% [markdown]
# # Correlation of parameters with every other parameter

# %%
df.corr()
# Out:
#                    Population [2011]  Popuation [2001]  Sex Ratio  Median Age  \
# Population [2011]           1.000000          0.969757  -0.068048   -0.031648
# Popuation [2001]            0.969757          1.000000  -0.099550   -0.033191
# Sex Ratio                  -0.068048         -0.099550   1.000000    0.156686
# Median Age                 -0.031648         -0.033191   0.156686    1.000000
# Avg Temp                    0.023085          0.017749   0.012762   -0.046883
# Toilets Avl                 0.503909          0.543846  -0.055500   -0.040233
# Water Purity               -0.003370          0.040403   0.066704    0.001998
# H Index                     0.027488          0.065548   0.032622    0.030653
# Female Population           0.999296          0.965875  -0.046222   -0.029244
# # of hospitals              0.413612          0.360317  -0.070828   -0.054834
# Foreign Visitors            0.096551          0.133692  -0.201233   -0.016207
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,cmap='viridis')
plt.ylim(12, 0)
# Out:
# (12.0, 0.0)

# %%
df.corr()['Covid Cases'][:-1].sort_values().plot(kind='bar')

# %%
plt.figure(figsize=(12,8))
sns.distplot(df['Covid Cases'])

# %% [markdown]
# # Number of missing values and frequency of categorical values

# %%
df.isnull().sum()
# Out:
# City                   0
# State                  0
# Type                   0
# Population [2011]     48
# Popuation [2001]     492
# Sex Ratio             10
# Median Age            18
# Avg Temp              17
# SWM                    4
# Toilets Avl           26
# Water Purity         158
# H Index              140
# Female Population    141
# # of hospitals        15
# Foreign Visitors      90
# Covid Cases            0
# dtype: int64

# %%
100* df.isnull().sum()/len(df)
# Out:
# City                  0.000000
# State                 0.000000
# Type                  0.000000
# Population [2011]     6.099111
# Popuation [2001]     62.515883
# Sex Ratio             1.270648
# Median Age            2.287166
# Avg Temp              2.160102
# SWM                   0.508259
# Toilets Avl           3.303685
# Water Purity         20.076239
# H Index              17.789072
# Female Population    17.916137
# # of hospitals        1.905972
# Foreign Visitors     11.435832
# Covid Cases           0.000000
# dtype: float64

# %%
df['Type'].nunique()
# Out:
# 37

# %%
df['Type'].value_counts()
# Out:
# C-1T              269
# M                 236
# M.Cl               59
# MPUA               44
# UA                 28
# M.B                28
# N.P.P              13
# T.M.C              13
# N.P                10
# C.T                 9
# M.Cl.               8
# M.C                 7
# C.M.C               7
# N.A.C               6
# N.P.P.              5
# T.P                 5
# T.M.C.              3
# C.B                 3
# CMC                 3
# NP                  3
# N.Pd                3
# M.Corp              2
# T.C                 2
# MB                  2
# N.P.                2
# M.B.                2
# N.A                 2
# NPP                 2
# C.T.                2
# T                   2
# T.P.                1
# M Cl                1
# U.A                 1
# Np                  1
# Nagar Parishad      1
# N.T                 1
# M.Corp.             1
# Name: Type, dtype: int64

# %%
df['SWM'].nunique()
# Out:
# 3

# %%
df['SWM'].value_counts()
# Out:
# HIGH      272
# LOW       260
# MEDIUM    251
# Name: SWM, dtype: int64

# %% [markdown]
# # Tabular evalution of boxplot of categorical data with covid cases and population

# %%
df.groupby('State')['Covid Cases'].describe()
# Out:
#                              count          mean            std      min  \
# State
# Andaman and Nicobar Islands    1.0   2538.000000            NaN   2538.0
# Andhra Pradesh                78.0   5439.961538    4285.732756   2054.0
# Assam                         21.0   5107.333333    3662.229448   2068.0
# Bihar                         51.0   6483.176471    5257.067040   2119.0
# Chandigarh                     1.0   7292.000000            NaN   7292.0
# Chhattisgarh                  11.0   5029.272727    5745.688298    449.0
# Delhi                          7.0  19032.714286   26978.749562   7812.0
# Goa                            3.0   2921.666667     104.643840   2808.0
# Gujarat                       41.0   4985.463415    6127.138978   1944.0
# Haryana                       21.0   4686.333333    3486.444182   1902.0
# Himachal Pradesh               1.0  10485.000000            NaN  10485.0
# Jammu and Kashmir              6.0   4677.000000    3881.772842   2045.0
# ...

# %%
df.groupby('SWM')['Covid Cases'].describe()
# Out:
#         count         mean           std    min     25%     50%      75%  \
# SWM
# HIGH    272.0  6429.158088  13213.135083  334.0  2274.5  2588.5  8283.25
# LOW     260.0  5864.773077  10273.896808  428.0  2269.5  2638.0  8800.25
# MEDIUM  251.0  6549.087649  15222.601662  358.0  2270.5  2543.0  8528.50
#
#              max
# SWM
# HIGH    145606.0
# LOW     150793.0
# MEDIUM  163115.0

# %%
df.groupby('Type')['Population [2011]'].describe()
# Out:
#                 count          mean           std        min         25%  \
# Type
# C-1T            255.0  3.151366e+05  1.811779e+05   100286.0   192254.50
# C.B               3.0  5.061600e+04  2.681946e+03    47845.0    49324.50
# C.M.C             7.0  6.368843e+04  1.446754e+04    37947.0    57368.50
# C.T               8.0  5.495250e+04  1.559607e+04    37699.0    47697.25
# C.T.              1.0  4.567500e+04           NaN    45675.0    45675.00
# CMC               2.0  7.482100e+04  6.467199e+03    70248.0    72534.50
# M               220.0  7.375350e+04  1.856498e+05    36828.0    47318.00
# M Cl              1.0  7.077700e+04           NaN    70777.0    70777.00
# M.B              24.0  5.441404e+04  1.551346e+04    36776.0    42484.00
# M.B.              2.0  7.900350e+04  2.891289e+04    58559.0    68781.25
# M.C               7.0  3.395704e+06  5.705143e+06    37289.0    58841.00
# M.Cl             56.0  7.401616e+04  1.125170e+05    36973.0    46004.75
# ...

# %%
df.groupby('Type')['Covid Cases'].describe()
# Out:
#                 count          mean            std     min       25%      50%  \
# Type
# C-1T            269.0   8217.438662    4376.359611   428.0   5595.00   8901.0
# C.B               3.0   2306.666667     243.052121  2081.0   2178.00   2275.0
# C.M.C             7.0   2502.857143     208.666743  2240.0   2322.00   2549.0
# C.T               9.0   2539.444444     238.455505  2192.0   2428.00   2582.0
# C.T.              2.0   2537.000000      70.710678  2487.0   2512.00   2537.0
# CMC               3.0   2311.666667     139.722344  2230.0   2231.00   2232.0
# M               236.0   2761.444915    2220.210192   334.0   2220.00   2408.5
# M Cl              1.0   1902.000000            NaN  1902.0   1902.00   1902.0
# M.B              28.0   2203.607143     209.330386  1591.0   2072.50   2184.5
# M.B.              2.0   2267.500000      24.748737  2250.0   2258.75   2267.5
# M.C               7.0  36230.285714   63073.854165  1531.0   2074.50   2274.0
# ...

# %%
df_1=df.copy()

# %%
df_1['Type']=df_1['Type'].replace(['M.B','N.P.P',              
'T.M.C',              
'N.P',             
'C.T',             
'M.Cl.',               
'C.M.C',               
'M.C',                 
'N.A.C',               
'N.P.P.',              
'T.P',                 
'NP',                  
'C.B',                 
'T.M.C.',              
'CMC',                 
'N.Pd',                
'M.B.',                
'N.P.',                
'N.A',                 
'T',                  
'MB',                  
'M.Corp',              
'NPP',               
'T.C',                 
'C.T.',                
'Nagar Parishad',      
'M.Corp.',             
'M Cl',                
'N.T',                 
'U.A',                 
'T.P.',                
'Np'], 'UA')

dummies = pd.get_dummies(df_1['Type'],drop_first=True)
df_1 = df_1.drop('Type',axis=1)
df_1 = pd.concat([df_1,dummies],axis=1)

# %%
df_1.head()
# Out:
#         City        State  Population [2011]  Popuation [2001]  Sex Ratio  \
# 0     Mumbai  Maharashtra         12442373.0        11978450.0      878.0
# 1      Delhi        Delhi         11007835.0         9879172.0      858.0
# 2  Bangalore    Karnataka          8436675.0         4301326.0      936.0
# 3  Hyderabad    Telangana          6809970.0         3637483.0      930.0
# 4  Ahmedabad      Gujarat          5570585.0         3520085.0      852.0
#
#    Median Age  Avg Temp     SWM  Toilets Avl  Water Purity   H Index  \
# 0        23.0      32.0  MEDIUM        219.0         150.0  0.700440
# 1        27.0      30.0  MEDIUM        215.0         196.0  0.920018
# 2        28.0      37.0    HIGH        212.0         102.0  0.097085
# 3        23.0      31.0  MEDIUM        217.0         118.0  0.827744
# 4        29.0      25.0     LOW        227.0         109.0  0.847941
#
#    Female Population  # of hospitals  Foreign Visitors  Covid Cases  M  M.Cl  \
# ...

# %%
df_2 = df_1.drop(columns = ['City','State','Popuation [2001]','Sex Ratio','Median Age','Avg Temp','Water Purity','H Index','Covid Cases'])

# %%
df_2.head()
# Out:
#    Population [2011]     SWM  Toilets Avl  Female Population  # of hospitals  \
# 0         12442373.0  MEDIUM        219.0         10924403.0           159.0
# 1         11007835.0  MEDIUM        215.0          9444722.0           148.0
# 2          8436675.0    HIGH        212.0          7896728.0           123.0
# 3          6809970.0  MEDIUM        217.0          6333272.0           110.0
# 4          5570585.0     LOW        227.0          4746138.0            73.0
#
#    Foreign Visitors  M  M.Cl  MPUA  UA
# 0         4408916.0  0     0     0   1
# 1         2379169.0  0     0     0   1
# 2          636502.0  0     0     1   0
# 3          126078.0  0     0     1   0
# 4          284973.0  0     0     1   0
